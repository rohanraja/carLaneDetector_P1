# %%
TEST_IMAGE_PATH = "test_images/challenge3.png"
TEST_IMAGE_PATH = "test_images/solidWhiteCurve.jpg"
height = 380,508
width = 700,830

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import helpers
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2

from helpers import *
from lanedetector import detectLanes
from io import BytesIO
from base64 import b64encode
from PIL import Image
from IPython.core.display import display, HTML

# %%
# Disable Autoscrolling
from IPython.display import display, Javascript

disable_js = """
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
}
"""

def load_ipython_extension(ip):
    display(Javascript(disable_js))
    print ("autoscrolling long output is disabled")

load_ipython_extension(0)
# Out:
# autoscrolling long output is disabled

# %%
def getImg():
    image = cv2.imread(TEST_IMAGE_PATH)
    #image = image[height[0]:height[1] , width[0]:width[1]]
    return image

# %%
# %matplotlib notebook  
    
image = getImg()
img = plt.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
hsv = hsv[:,:,:]
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
image = gaussian_blur(image, 5)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
skyPart = np.bitwise_and(hsv[:,:,0] > 95, hsv[:,:,0] < 105)
hsv = hsv[:,:,0]
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
image = gaussian_blur(image, 5)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
hsv = hsv[:,:,1]
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
image = gaussian_blur(image, 5)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
hsv = hsv[:,:,1] < 20
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
image = gaussian_blur(image, 5)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
hsv = hsv[:,:,2]
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
image = getImg()
image = gaussian_blur(image, 5)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
hsv = hsv[:,:,2] > 200
#sky = np.bitwise_not(skyPart)
#hsv = np.bitwise_and(hsv, sky)
plt.figure()
plt.imshow(hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
hsv
masked = cv2.bitwise_and(image, image, mask=hsv.astype(np.uint8))
plt.figure()
plt.imshow(hsv.astype(np.uint8))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
hsv.astype(np.uint8)[313][626]*255
hsv.shape
# Out:
# (540, 960)
